# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob

# %%
data = open("testcreation/tests/lab21.out").read().split(' ')[:-1]
plt.plot([float(i) for i in data])
plt.show()

# %%
to_test = glob.glob("./testcreation/tests/lab*.out")
to_test += glob.glob("./testcreation/tests/ran*.out")
sums = []
names = []
for i in to_test:
    data = open(i).read().split(' ')[:-1]
    names.append(i[len('./testcreation/tests/'):])
    sums.append(sum([float(i) for i in data]))
d = np.array([names, sums]);
d = np.transpose(d);
df = pd.DataFrame(d, columns =['names', 'time'])

# %%
df = df.sort_values(by=['time'])

# %%
df[:]
# Out:
#                  names                   time
# 50   randomw8_0.15.out                      0
# 51   randomw1_0.15.out                      0
# 53    random2_0.35.out                      0
# 21  randomw10_0.07.out                      0
# 55    random4_0.35.out                      0
# 56  randomw10_0.11.out                      0
# 26    random7_0.25.out                      0
# 68   randomw3_0.15.out                      0
# 27   randomw4_0.15.out                      0
# 28   randomw7_0.07.out                      0
# 74    random7_0.35.out                      0
# 75   randomw5_0.15.out                      0
# 79   randomw6_0.15.out                      0
# 81   randomw9_0.15.out                      0
# 29    random9_0.35.out                      0
# 82    random7_0.15.out                      0
# 84   randomw3_0.11.out                      0
# 30   randomw2_0.15.out                      0
# 87   randomw9_0.11.out                      0
# 89  randomw10_0.15.out                      0
# 90    random8_0.35.out                      0
# 31   randomw7_0.11.out                      0
# 34    random9_0.25.out                      0
# 95   randomw7_0.15.out                      0
# 47   randomw2_0.11.out                      0
# 46   randomw7_0.03.out                      0
# 39    random1_0.35.out               0.000652
# 93   randomw1_0.11.out  0.0008049999999999999
# 64    random1_0.25.out  0.0008870000000000001
# 69   randomw1_0.07.out  0.0009489999999999999
# ..                 ...                    ...
# 63    random7_0.05.out    0.07744300000000001
# 72    random9_0.05.out    0.08339200000000001
# 80  randomw10_0.03.out    0.10437299999999992
# 65   random10_0.35.out    0.10601199999999997
# 58   random10_0.25.out    0.10796299999999993
# 43    random8_0.25.out               0.109846
# 11            lab5.out    0.11449200000000007
# 4             lab6.out    0.11623900000000001
# 78   random10_0.05.out    0.12480799999999995
# 66   randomw8_0.03.out    0.12484199999999994
# 71   randomw9_0.03.out    0.13164599999999996
# 54    random9_0.15.out    0.13244699999999995
# 3             lab4.out    0.13762999999999997
# 76   random10_0.15.out    0.15553400000000006
# 92   randomw9_0.07.out    0.17478999999999986
# 1             lab7.out               0.254867
# 5             lab8.out               0.322709
# 15            lab9.out     0.4755229999999999
# 13           lab12.out               0.857243
# 20           lab10.out     1.3087799999999994
# 6            lab11.out     1.5736420000000002
# 17           lab16.out      2.135062999999998
# 9            lab13.out     2.3882330000000005
# 8            lab14.out     2.9638329999999953
# 16           lab18.out     3.1042280000000027
# 18           lab19.out     3.1419419999999962
# 14           lab15.out      3.210773000000007
# 7            lab20.out      4.523248000000004
# 12           lab17.out               5.351258
# 0            lab21.out      7.896137999999996
#
# [101 rows x 2 columns]
